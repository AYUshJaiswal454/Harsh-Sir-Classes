# %% [markdown]
# <a href="https://colab.research.google.com/github/AYUshJaiswal454/Harsh-Sir-Classes/blob/main/lecture_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst = [1,2,3,'hello','c',[2,4]]
print(lst)

# lst.append(3)
lst.append([2,3,4])
print(lst)
# Out:
# [1, 2, 3, 'hello', 'c', [2, 4]]
# [1, 2, 3, 'hello', 'c', [2, 4], [2, 3, 4]]

# %% [markdown]
# append

# %%
lst = [1,2,3,'hello','c',[2,4]]
print(lst)

lst.extend([2,3,4])
print(lst)
# Out:
# [1, 2, 3, 'hello', 'c', [2, 4]]
# [1, 2, 3, 'hello', 'c', [2, 4], 2, 3, 4]

# %% [markdown]
# extend

# %%
lst = [1,2,3,'hello','c',[2,4]]
print(lst)

lst.insert(2,[2,3,4])
print(lst)
# Out:
# [1, 2, 3, 'hello', 'c', [2, 4]]
# [1, 2, [2, 3, 4], 3, 'hello', 'c', [2, 4]]

# %% [markdown]
# insert

# %%
lst = [1,2,3,'hello','c',[2,4]]
print(lst)


lst.pop()
print(lst)
# Out:
# [1, 2, 3, 'hello', 'c', [2, 4]]
# [1, 2, 3, 'hello', 'c']

# %% [markdown]
# pop

# %%
lst = [1,2,3,'hello','c',[2,4]]
print(lst)

lst.remove(2)
print(lst)
# Out:
# [1, 2, 3, 'hello', 'c', [2, 4]]
# [1, 3, 'hello', 'c', [2, 4]]

# %% [markdown]
# remove

# %%
lst = [1,2,3,'hello','c',[2,4]]
print(lst)

print(lst.index(3))
print(lst.index(1))
# Out:
# [1, 2, 3, 'hello', 'c', [2, 4]]
# 2
# 0

# %% [markdown]
# index

# %%
lst = [1,2,3,'hello','c',[2,4]]
print(lst)

print(lst.count(2))


lst = [1,2,3,'hello','c',[2,4],2,3,44,7,8,3]
print(lst.count(3))
# Out:
# [1, 2, 3, 'hello', 'c', [2, 4]]
# 1
# 3

# %% [markdown]
# count

# %%
lst = [1,2,3,5,6,3,5,6,8,3,2,8,33]
print(lst)

lst.sort()
print(lst)
# Out:
# [1, 2, 3, 5, 6, 3, 5, 6, 8, 3, 2, 8, 33]
# [1, 2, 2, 3, 3, 3, 5, 5, 6, 6, 8, 8, 33]

# %% [markdown]
# sort

# %%
lst = [1,2,3,44,65,4,6,7,3,5,2,33,5]
print(lst)

print(sum(lst))
# Out:
# [1, 2, 3, 44, 65, 4, 6, 7, 3, 5, 2, 33, 5]
# 180

# %% [markdown]
# sum

# %%
lst = [1,2,3,44,65,4,6,7,3,5,2,33,5]
print(lst)

print(max(lst))
# Out:
# [1, 2, 3, 44, 65, 4, 6, 7, 3, 5, 2, 33, 5]
# 65

# %% [markdown]
# max

# %%
lst = [1,2,3,44,65,4,6,7,3,5,2,33,5]
print(lst)

print(min(lst))
# Out:
# [1, 2, 3, 44, 65, 4, 6, 7, 3, 5, 2, 33, 5]
# 1

# %% [markdown]
# min

# %%
lst = [1,2,3,4,2,1,3,4,9,8,6,4,6,4]
print(lst)



a = sorted(lst)
print(a)
# Out:
# [1, 2, 3, 4, 2, 1, 3, 4, 9, 8, 6, 4, 6, 4]
# [1, 1, 2, 2, 3, 3, 4, 4, 4, 4, 6, 6, 8, 9]

# %% [markdown]
# sorted

# %%
# TUPLE

tp = (1,2,33,4)

a = tuple(sorted(tp))
print(a)
# Out:
# (1, 2, 4, 33)

# %% [markdown]
# In Tuple
#
# We use- count(), index(), len(), sum(), max(), min(), sorted()

# %%
tp = (1,2,33,4,5,66,7,4,3,9,4,2)
print(tp)

print(tp.count(8))
# Out:
# (1, 2, 33, 4, 5, 66, 7, 4, 3, 9, 4, 2)
# 0

# %% [markdown]
# count

# %%
tp = (1,2,33,4,5,66,7,4,3,9,4,2)
print(tp)

print(tp.index(66))
# Out:
# (1, 2, 33, 4, 5, 66, 7, 4, 3, 9, 4, 2)
# 5

# %% [markdown]
# index

# %%
tp = (1,2,33,4,5,66,7,4,3,9,4,2)
print(tp)

print(len(tp))
# Out:
# (1, 2, 33, 4, 5, 66, 7, 4, 3, 9, 4, 2)
# 12

# %% [markdown]
# length

# %%
tp = (1,2,33,4,5,66,7,4,3,9,4,2)
print(tp)

print(sum(tp))
# Out:
# (1, 2, 33, 4, 5, 66, 7, 4, 3, 9, 4, 2)
# 140

# %% [markdown]
# sum

# %%
tp = (1,2,33,4,5,66,7,4,3,9,4,2)
print(tp)

print(max(tp))
# Out:
# (1, 2, 33, 4, 5, 66, 7, 4, 3, 9, 4, 2)
# 66

# %% [markdown]
# maximum

# %%
tp = (1,2,33,4,5,66,7,4,3,9,4,2)
print(tp)

print(min(tp))
# Out:
# (1, 2, 33, 4, 5, 66, 7, 4, 3, 9, 4, 2)
# 1

# %% [markdown]
# minimum

# %%
tp1 = ()
for i in range(0,len(tp1),1) :

  # tp1 = input(tp1[i])
tp2 = ()
for j in range(0,len(tp2),1) :
  tp2 = input(tp2[j])

  print(tp1)

# %%
lst1 = []
lst2 = []

size = int(input())

for i in range(size) :
  x = int(input())

  lst1.append(x)



for i in range(size) :
  y = int(input())

  lst2.append(y)


  lst3 = []

for i in range(size) :
    lst3.append(lst1[i] + lst2[i])
    print(lst3)
# Out:
# 5
# 1
# 2
# 3
# 7
# 44
# 1
# 2
# 4
# 5
# 6
# [2]
# [2, 4]
# [2, 4, 7]
# [2, 4, 7, 12]
# [2, 4, 7, 12, 50]
