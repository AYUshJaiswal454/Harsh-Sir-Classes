# %% [markdown]
# <a href="https://colab.research.google.com/github/AYUshJaiswal454/Harsh-Sir-Classes/blob/main/Lecture3_(function).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fun_name(parameters):
  # body of the function

# %%
  def add_No(a,b):
    return a+b

print(add_No(3,5))
# Out:
# 8

# %%
# lamda function
x = lambda a : 2 * a
print(x(5))


x = lambda a, b : b * a
print(x(2, 3))
# Out:
# 10
# 6

# %% [markdown]
# STRING

# %%
st = ""
print (len(st))
# Out:
# 0

# %%
# UPPERCASE

st = "ayush jaiswal"
st1 = st.upper()
print(st1)
# Out:
# MIRAI

# %%
# LOWERCASE

st = "AYUSH JAISWAL"
stNew = st.lower()
print(stNew)
# Out:
# ayush jaiswal

# %%
# TITLE

st = "AYUSH JAISWAL"
stNew = st.title()
print(stNew)
# Out:
# Ayush Jaiswal

# %%
# CAPITALISE

st = "AYUSH JAISWAL"
stNew = st.capitalize()
print(stNew)
# Out:
# Ayush jaiswal

# %%
# STRIP

st = "    AYUSH JAISWAL"
print(st)
stNew = st.strip()
print(stNew)
# Out:
#     AYUSH JAISWAL
# AYUSH JAISWAL

# %%
a = " today "
b = "    weather     "
c = "is GooD   "

A = a.strip()
B = b.strip()
C = c.strip()


Ans = print((A + ' ' + B + ' ' + C).capitalize())
# Out:
# Today weather is good

# %%
# replace

st = "Today weather is good"
newSt = st.replace("good", "bad")
print(newSt)
# Out:
# Today weather is bad

# %%
# find

st = "Today weather is good"
ans = st.find("is")
print(ans)
# Out:
# 14

# %%
# startswith

st = "Today weather is good"
st1=st.startswith("today")
print(st1)
st2=st.startswith("Today")
print(st2)
# Out:
# False
# True

# %%
# endswith

st = "Today weather is good"
st1 = st.endswith("good")
print(st1)
# Out:
# True
